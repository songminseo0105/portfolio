# %% [markdown]
# GPlearn

# %%
import sys
# !{sys.executable} -m pip install gplearn
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from gplearn.genetic import SymbolicRegressor 
from gplearn.functions import make_function

# %%
def my_square(x):
    return np.square(x)

square = make_function(function=my_square, name='square', arity=1)
#arity = 1 -> 단항 연산자

# %%
df = pd.read_csv('my_data.csv')

X_train = df[['X0', 'X1', 'X2']].values
y_train = df['Y'].values

# gplearn 실행
function_set = ['add', 'sub', 'mul', 'div','sqrt', square]
est_gp = SymbolicRegressor(population_size=1000, generations=20, function_set=function_set, verbose=1, random_state=42) 
#verbose=1 -> 수행 진행 실시간 출력 ,random_state= 42-> 무작위 

est_gp.fit(X_train, y_train) #데이터 입력하고 유전자 알고리즘 수행
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    17.19      2.26625e+29        8          3.31282              N/A     10.14s
#    1    10.07          55.2956       21           2.4654              N/A     10.34s
#    2    13.21          2749.52       21           2.4654              N/A      8.66s
#    3    13.37          2852.47        7          1.62454              N/A      9.37s
#    4    17.98          3203.46       18          1.62454              N/A      8.71s
#    5    20.56          906.207       18          1.62454              N/A      8.25s
#    6    17.98          61.3026       13          1.62284              N/A      7.34s
#    7    11.95          44.9632        7          1.62454              N/A      6.05s
# ...

# %%
print(f" 최종  수식: {est_gp._program}")


fitness_history = est_gp.run_details_['best_fitness']
final_mse = min(fitness_history)
final_gen = fitness_history.index(final_mse)

print(f" 해당 수식의 세대:  {final_gen} ")
print(f"해당 수식의 MSE: {final_mse:.5e}")
# Out:
#  최종  수식: mul(X0, div(X1, square(X2)))
#  해당 수식의 세대:  6
# 해당 수식의 MSE: 1.62284e+00
